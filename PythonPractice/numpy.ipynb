# %%
import numpy as np
steps = np.array([3191, 230, 9193, 4670, 164, 3820, 9093])
print(np.min(steps))
print(np.max(steps))
print(np.sum(steps))
print(round(np.average(steps), 2))
# Out:
# 164
# 9193
# 30361
# 4337.29
