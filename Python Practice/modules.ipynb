# %% [markdown]
# # Modules
# What are modules?
# * Modules are reusable pieces of code that can be imported and used in other parts of a program. They help to organize code and promote code reusability.
# * In Python, a module is a file containing Python definitions and statements. The file name is the module name with the suffix `.py` added.
# **Example:**
# ```python
# # my_module.py
# def greet(name):
#     return f"Hello, {name}!"
# ```To use this module in another file, you can import it:
# ```python# main.py
# import my_module
# print(my_module.greet("Alice"))
# ```Output:
# ```Hello, Alice!
# ```
# * Modules can also contain variables, classes, and other functions. They can be imported using the `import` statement, and you can access the contents of the module using dot notation.
# **Example:**```python
# # import modules
# import math
# import random
# # use functions from the modules
# print(math.sqrt(16))  # Output: 4.0
# print(random.randint(1, 10))  # Output: a random integer between 1 and 10
# ```* You can also import specific functions or variables from a module using the `from` keyword.
# **Example:**
# ```python
# from math import sqrt
# print(sqrt(25))  # Output: 5.0

# %%
import random
symbols = ['🍒',' 🍇', '🍉', '7️⃣']
def play():
    while True:
        results = random.choices(symbols, k=3)
        print(' | '.join(results))
        if results ==  ['7️⃣','7️⃣','7️⃣']:
            print("Jackpot!!!")
        else: print("Try Again")
        while True:
            want = input("Type 'Y' to keep playing or 'N' to stop playing: ")
            if want in ['Y', 'N']:
                break
        if want == 'Y':
            print("Lets gamble")
            continue
        if want == 'N':
            print("damn okay Goodbye")  
            break
        
play()
# Out:
#  🍇 | 7️⃣ |  🍇
# Try Again
# damn okay Goodbye

# %%
# Birthday Message
import random 
bday_messages = [
'Hope you have a very Happy Birthday! 🎈',
'It\'s your special day – get out there and celebrate! 🎉',
'You were born and the world got better – everybody wins! 🥳',
'Have lots of fun on your special day! 🎂',
'Another year of you going around the sun! 🌞 '
]
random_message = random.choice(bday_messages)

# %%
from math import pi
from random import choice as ch
planets = [
  'Mercury',
  'Venus',
  'Earth',
  'Mars',
  'Saturn'
]
random_planet = ch(planets)
r = 0
if random_planet == "Mercury":
  r += 2440
elif random_planet == "Venus":
  r += 6052
elif random_planet == "Earth":
  r += 6371
elif random_planet == "Mars":
  r += 3390
elif random_planet == "Saturn":
  r += 58232
else: print("Oops! An error occured.")
area = 4 * pi * r**2
print(f"{random_planet} area is {round(area, 2)} kmsquare")
# Out:
# Earth area is 510064471.91 kmsquare
